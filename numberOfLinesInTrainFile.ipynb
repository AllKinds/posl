# %%
with open('./input-files/heb-pos.train') as file:
    lines = list(filter(None, (line.rstrip() for line in file)))

# %%
print(lines)
# Out:
# ['yyQUOT\tyyQUOT', 'THIH\tVB', 'NQMH\tNN', 'W\tCC', 'BGDWL\tRB', 'yyDOT\tyyDOT', 'GM\tMOD', 'IHWDIM\tNN', 'NMCAIM\tVB', 'ETH\tRB', 'EL\tIN', 'H\tH', 'KWWNT\tNN', 'yyQUOT\tyyQUOT', 'AMRW\tVB', 'ANFI\tNNT', 'KK\tNNP', 'B\tIN', 'ET\tNNT', 'MSE\tNNT', 'H\tH', 'HLWWIIH\tNN', 'yyDOT\tyyDOT', 'AIF\tNN', 'LA\tRB', 'NISH\tVB', 'LHSTIR\tVB', 'ZAT\tPRP', 'yyDOT\tyyDOT', 'LA\tMOD', 'H\tH', 'MNHIGIM\tNN', 'F\tREL', 'HSITW\tVB', 'L\tIN', 'RCX\tNN', 'yySCLN\tyySCLN', 'LA\tMOD', 'XLQIM\tNN', 'B\tIN', 'H\tH', 'CIBWR\tNN', 'H\tH', 'ZH\tJJ', 'yyCM\tyyCM', 'F\tREL', 'LAWRK\tIN', 'CIR\tNNT', 'H\tH', 'HLWWIIH\tNN', 'RQMW\tVB', 'TWKNIWT\tNN', 'KICD\tQW', 'LPGWE\tVB', 'B\tIN', 'ERBIM\tNN', 'KBR\tMOD', 'B\tIN', 'H\tH', 'IMIM\tNN', 'H\tH', 'QRWBIM\tJJ', 'yyDOT\tyyDOT', 'SWPR\tNNT', 'yyQUOT\tyyQUOT', 'H\tH', 'ARC\tNN', 'yyQUOT\tyyQUOT', 'B\tIN', 'H\tH', 'CPWN\tNN', 'yyCM\tyyCM', 'MWSIP\tVB', 'yyCLN\tyyCLN', 'IRIWT\tNN', 'NFMEW\tVB', 'ATMWL\tRB', 'B\tIN', 'FEH\tNN', '2000\tCD', 'B\tIN', 'H\tH', 'ERB\tNN', 'B\tI
# ...

# %%
len(lines)
# Out:
# 127884
